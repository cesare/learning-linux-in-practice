# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv("results/sched_nice.tsv", delimiter="\t", header=None, names=("id", "elapsed", "progress"))

# %%
sns.lmplot("elapsed", "id", data=df, hue="id", markers=".")

# %%
sns.lmplot("elapsed", "progress", data=df, hue="id", scatter=True, markers=".")
